# %% [markdown]
# ## Imports

# %%
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
from displayData import displayData, displayImage

# %% [markdown]
# ## Cargar datos

# %%
data = loadmat('ex4data1.mat')

Y = data['y'].ravel()
X = data['X']

w = loadmat('ex4weights.mat')

# %% [markdown]
# ## Mostrar ejemplos

# %%
sample = np.random.choice(X.shape[0], 100)
fig, ax = displayData(X[sample, :])

# %% [markdown]
# ## ONEHOT

# %%
m = len(Y)
input_size = X.shape[1]
num_labels = 10

Y = (Y - 1)
Y_onehot = np.zeros((m, num_labels))

for i in range(m):
    Y_onehot[i][Y[i]] = 1

# %% [markdown]
# ## Inicializar valores

# %%
# m = X.shape[0]
# X = np.hstack([np.ones([m, 1]), X])
# n = X.shape[1]
# print(theta.shape)

# %% [markdown]
# ## Inicializar Thetas

# %%
def iniThetas (sizes):
    """
    Input: array of sizes without the +1
    Output: dictionary of thetas init @0, except the first element -> @1
    
    
    For example:
        Theta1 = (25, 401)
        Theta1 = (10, 26)
    """
    
    d = dict()
    for i in range(1, len(sizes)):
        name = "Theta" + str(i)
        aux = np.zeros((sizes[i], sizes[i - 1]))
        aux = np.hstack([np.ones([sizes[i], 1]), aux])
        d[name] = aux
        # print(d[name])
        
    return d
        
d = iniThetas([400, 25, 10])

# %% [markdown]
# ## Función Sigmoide

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %% [markdown]
# ## Forward Propagation

# %%
def forward_prop(X, w):
    a1 = X
    a1 = np.hstack([np.ones([X.shape[0], 1]), a1])

    z2 = np.dot(w['Theta1'], a1.T)
    a2 = sigmoid(z2).T
    a2 = np.hstack([np.ones([a2.shape[0], 1]), a2])

    z3 = np.dot(w['Theta2'], a2.T)
    h = sigmoid(z3).T

    return a1, z2, a2, z3, h

# %% [markdown]
# ## Función de Coste

# %%
def coste(d, X, Y, K, lam):
    m = X.shape[0]
    J_theta = 0    
    aux = 0
    _, _, _, _, h_theta = forward_prop(X, d)
    
    for i in range(m):
        aux +=np.sum(-Y[i] * np.log(h_theta[i]) - (1 - Y[i]) * np.log(1 - h_theta[i]))
            
    
    J_theta = (1 / m) * aux
    
    # Regularizacion
    reg = 0

    for theta in w.keys():
        if "__" not in theta:
            reg += np.sum(np.square(w[theta][:, 1:]))

    reg *= (lam /(2 * m))

    # Coste Regularizado
    J_theta += reg
    
    return J_theta

# %%
# PRUEBAS
print("Coste sin regularizar:\t{}".format(coste(w, X, Y_onehot, Y_onehot.shape[0], 0)))
print("Coste regularizado:\t{}".format(coste(w, X, Y_onehot, Y_onehot.shape[0], 1)))
# Out:
# Coste sin regularizar:	0.28762916516131876
# Coste regularizado:	0.3837698590909235

# %% [markdown]
# ## Función de Gradiente

# %%
def gradiente(w, X, Y, reg):
    """
    Calcula el coste de la gradiente
    """
    m = X.shape[0]
    
    d = dict()
    d["delta1"] = np.zeros(w["Theta1"].shape)
    d["delta2"] = np.zeros(w["Theta2"].shape)
    
    a1, z2, a2, z3, h_theta = forward_prop(X, w)
    
    d
    
    
gradiente(w, X, Y, 0)

# %% [markdown]
# ## Gradiente

# %% [markdown]
# ## Backprop

# %%
def backprop(params_rn, num_entradas, num_ocultas, num_etiquetas, X, Y, reg):
    """
    Esta función devuelve una tupla (coste, gradiente) con el coste y el gradiente de
    una red neuronal de tres capas, con num_entradas, numocultas nodos en la capa
    oculta y num_etiquetas nodos en la capa de salida. Si m es el número de ejemplos
    de entrenamiento, la dimensiónde de 'X' es (m, num_entradas) y la de 'y' es (m, num_etiquetas)
    """
    w["Theta1"] = np.reshape(params_rn[:num_ocultas * (num_entradas + 1)],
                        (num_ocultas, (num_entradas + 1)))

    w["Theta2"] = np.reshape(params_rn[num_ocultas * (num_entradas + 1):],
                        (num_etiquetas, (num_ocultas + 1)))
    
    return coste(w, X, Y_onehot, Y_onehot.shape[0], 0)

# %%
# Pruebas
params_rn = np.concatenate(
    (
        np.ravel(w["Theta1"]),
        np.ravel(w["Theta2"])
    )
)

backprop(params_rn, X.shape[1], 25, Y_onehot.shape[1], X, Y_onehot, 1)
# Out:
# 0.28762916516131876
